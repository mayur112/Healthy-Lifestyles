# %%
print("Welcome to our healthy lifestyle and live a healthier onwards")
print("Some best Healthy and better life Tips")

while True:
    v=str(input("\nDID YOU TAKE VACCINE(yes/no):"))
    if(v=='yes'):
        n=int(input("\nENTER YOUR 'AGE':"))
        print("")
        print("**Don't worry if you get sick from the list below.If it is an illness, what to do or what not to do for that illness and what care should be taken so that you can live your life longer for this ,read the following carefully..**")
        print("DISEASE NAME=\n1).diabetes\n2).cancer\n3).heart attack\n4).paralysis\n5).thyroid\n6).hearing loss\n7).backache\n8).neck pain\n9).depression\n10).pulmonary\n11).tuberculosis etc...\n")

        if(n==65)or(n==66)or(n==67)or(n==68)or(n==69)or(n==70):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicte,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")


        elif(n==71)or(n==72)or(n==73)or(n==74)or(n==75):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicte,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")


        elif(n==76)or(n==77)or(n==78)or(n==79)or(n==80):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicte,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")

        elif(n==81)or(n==82)or(n==83)or(n==84)or(n==85):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicte,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")

        elif(n==86)or(n==87)or(n==88)or(n==89)or(n==90):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicte,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")

        elif(n==91)or(n==92)or(n==93)or(n==94)or(n==95):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicte,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")

        elif(n==96)or(n==97)or(n==98)or(n==99)or(n==100):

            p=str(input("\nEnter a Disease Name:"))
            print("")
            if(p=='diabetes'):
                print("\n\nWhat is Diabetes?\n\tDiabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.")

                i=int(input("\nEnter Your recently check blood sugar(After meal):"))
                if(i>126):
                    print(i,"=mg/dl higher indicate,you have diabetes.\n your sugar level is higher than normal range")
                    print("PRECAUTIONS:\n1]Cut Sugar and Refined Carbs From Your Diet\n2]Work Out Regularly\n3]Drink Water as Your Primary Beverage\n4]Lose Weight If You're Overweight or Obese\n5]Quit Smoking\n6]Follow a Very-Low-Carb Diet\n7]Avoid Sedentary Behaviors\n")
                    print("EXERCISE FOR DIABETES PATIENT:\n1] Walking. Walking is one of the easiest aerobic exercises to do, and you don't need any equipment - just your two feet\n2]yoga\n3]pilates\n4]dance\n5]bicycle or elliptical machine\n6]high-intensity interval training(HIIT)\n7]Resistance training\n")
                    print("Ayurvedic Medicine For Diabetes:\nFor treatment of type 2 diabetes, the herbs M. charantia, Pterocarpus marsupium, and Trigonella foenum greacum have been proven most successful")

                elif(i<70):
                    print(i,"=A blood sugar level below 70 mg/dL is low and can harm you")
                    print("Do:\nConsuming high-sugar foods or drinks, such as orange juice or regular fizzy drinks, can treat this condition.\nAlternatively, medication can be used to raise blood sugar levels. It's also important that a doctor identifies and treats the underlying cause")
                else:
                    print(i,"=your blood sugar is normal\nDo Exercies daily")

            elif(p=='heart attack'):
                print("PRECAUTIONS:\n1]Quit smoking\n2]keep check and control the chlestrol levels\n3]control blood pressure levels\n4]Exercise and be physically fit\n5]Loose the extra weights\n6]Choose a diet for a healthy heart\n7]Get proper sleep\n8]Manage stress(reduced stress)\n")
                print("EXERCIES:\n1]Choose an aerobic activity such as walking\n2]swimming\n3]light jogging, or biking Do this at least 3 to 4 times a week\n4]Always do 5 minutes of stretching or moving around to warm up your muscles and heart before exercising\n")
                print("MEDICINE:\n1]Aspirin. The 911 operator might tell you to take aspirin, or emergency medical personnel might give you aspirin immediately\n2]Thrombolytics\n3]Antiplatelet agents.... • Other blood-thinning medications\n4]Pain relievers\n5]Beta blockers\n6]Nitroglycerin\n")
            elif(p=='cancer'):
                print("PRECAUTIONS:\n1]Don't use tobacco. Using any type of tobacco puts you on a collision course with cancer\n2]Eat a healthy diet\n3]Maintain a healthy weight and be physically active\n4]Protect yourself from the sun\n5]Avoid risky behaviors\n6]Get regular medical care\n7]avoif alcohol\n")
                print("EXERCISE:\n1]Breathing exercises. Some people with cancer may have shortness of breath or difficulty breathing\n2]Active During and After Cancer\n3]Stretching. Stretching regularly can improve your flexibility and posture\n4]Balance exercises\n5]Aerobic exercise\n6]Strength training\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]cumin\n4]turmeric\n5]lcorice root\n")

            elif(p=='paralysis'):
                print("PRECAUTIONS:\n1]Get more exercise at least 30 minutes of activity a day, and more, if possible. Quit smoking, if you smoke\n2]If needed, take blood pressure medicines\n3]lose weight\n4]exercise more\n5]If you drink - do it in moderation\n6]Treat atrial fibrillation\n7]Treat diabetes\n8]Quit smoking\n")
                print("EXERCISE:\n1]Passive exercise involves assisting your affected limbs through a movement. This is where stroke patients with paralysis should start. Passive exercise helps with paralysis recovery because it involves using your non-affected side to move your paralyzed muscles, and any type of movement sends signals to the brain\n2]Choose an aerobic activity such as walking\n")
                print("MEDICINE:\n1]Ashwagandha. Ashwagandha (Withania somnifera) is a small woody plant native to India and North Africa\n2]Boswellia\n3]Brahmi\n4]Cumin\n5]Turmeric\n6]Licorice root\n7]Gotu kola\n8]Bitter melon\n")

            elif(p=='hearing loss'):
                print("PRECAUTIONS:\n1]move away from sources of loud noises (such as loudspeakers) try to take a break from the noise every 15 minutes\n2]ive your hearing about 18 hours to recover after exposure to lots of loud noise\n3]consider wearing earplugs - you can buy re-usable musicians' earplugs that reduce the volume of music but do not muffle it\n")
                print("EXERCISE:\n1]Yoga is a recommended exercise to improve your hearing\n2]t combines the relaxation of meditation with the health benefits of a good workout\n3]One of the best ways to maintain your hearing health is to practice hearing\n")
                print("MEDICINES:\nDrops for the Ear::\n1]Apamarga Kshara Taila: 2 to 4 drops, to be instilled in the ear twice a day\n2]Bilva Taila: 2 to 4 drops, to be instilled in the ear twice a day\n3]Bilvadi Taila: 2 to 4 drops, to be instilled in the ear twice a day\n4]Dashamula Taila: 2 to 4 drops, to be instilled in the ear twice a day\n")
            elif(p=='backache'):
                print("PRECAUTIONS:\n1]Do back-strengthening and stretching exercises at least 2 days a week\n2]Stand and sit up straight\n3]Avoid heavy lifting. If you do lift something heavy,bend your knees and keep your back straight\n4]Get active and eat healthy. Being overweight can strain your back\n")          
                print("EXERCISE:\n1]Daily activities such as housecleaning and gardening\n2]Low-impact aerobics\n3]Resistance exercises\n4]Stationary cycling\n5]Stretching exercises\n6]Swimming\n")
                print("MEDICINE:\nAyurveda recommends the use of herbs like ::\n1]Guggul\n2]Nirgundi\n3]Shallaki\n4]Ginger to treat back pain\n")
            elif(p=='thyroid'):
                print("PRECAUTIONS:\n1]Avoid Processed Food: A lot of chemicals can alter the thyroid hormone production\n2]Avoid Soy: Limit the soy intake as it alters the hormone production\n3]Stop Smoking\n4]Reduce Stress\n5]skip the iodine\n6]watch your soy intake\n7]try selenium\n")
                print("EXERCIES:\n1]Yoga\n2]pailates\n3]aerobic activity\n4]cardio\n5]weight training(strengthening)\n6]flexibility\n")
                print("MEDICINE:\n1]curevedaTM herbal thyro\n2]OZiva plant based DHT blocker\n3]Aayucure thaiambro ayurvedic")
            elif(p=='neck pain'):
                print("PRECAUTIONS:\n1]Apply heat or ice to the painful area\n2]Take over-the-counter pain relievers such as ibuprofen or acetaminophen\n3]Keep moving, but avoid jerking or painful activities\n4]Do slow range-of-motion exercises, up and down, side to side, and from ear to ear\n")
                print("MEDICIE:\n1]Ayurveda Panchakarma therapies for treating cervical spondylosis include Abhyanga swedam\n2] Elakizhi\n3]Nasyam\n4]Shirovasti or shirodhara\n5]Sarvangadhara\n6]Greeva vasti\n7]Navara kizhi\n8]Pizhichil etc to relieve pain\n9]inflammation of muscles and ligaments and to improve the flexibility of neck bone joints\n")
                print("EXERCISE:\n1]Side Rotation Keep your head squarely over your shoulders and your back straight\n2]Slowly turn your head to the right until you feel a stretch in the side of your neck and shoulder\n3] Hold the stretch for 15-30 seconds, and then slowly turn your head forward again. Repeat on your left side")
            elif(p=='depression'):
                print("PRECAUTION:\n1]Never use a wet electrical device\n2] If the power is out, use flashlights instead of candles\n3]Prevent carbon monoxide poisoning\n4]Be careful near damaged buildings\n5]stay away from power lines\n6]Protect yourself from animals and pests\n")
                print("EXERCISE:\n1]Break a Sweat for Depression Relief\n2]Get  your walk on\n3]try tai chi\n")
                print("MEDICINES:\n1]Citalopram (Celexa)\n2]Escitalopram (Lexapro)\n3]Fluoxetine (Prozac, Sarafem, Symbyax)\n4]Fluvoxamine (Luvox)\n5]Paroxetine (Paxil, Pexeva)\n")
            elif(p=='tuberculosis'):
                print("PRECATUIIONS:\nThe risk of infection can be reduced by using a few simple precautions:\n1]good ventilation: as TB can remain suspended in the air for several hours with no ventilation\n2]natural light: UV light kills off TB bacteria\n3]good hygiene: covering the mouth and nose when coughing or sneezing reduces the spread of TB bacteria\n")
                print("EXERCISE:\n1]Stationary cycling\n2] resistance training and light jogging are great ways to make sure that the TB infection that was once in your system has been completely eradicated\n3]weight training\n")
                print("MEDICINES:\n1]Anti-tubercular Drugs – Rifampicin, Pyrazinamide, Ethambutol, Isoniazid were supplied from the Hospital\n2]Ayurvedic drugs Aswagandha (Withania somnifera) and Chyawanprash\n")
            elif(p=='pulmonary'):
                print("PRECAUTIONS:\n1]The best way to prevent COPD is to never start smoking, and if you smoke, quit\n2]Talk with your doctor about programs and products that can help you quit\n3]stay away from secondhand smoke, which is smoke from burning tobacco products, such as cigarettes, cigars, or pipes\n")
                print("EXERCISE:\n1]Aerobic exercise is good for your heart and lungs and allows you to use oxygen more efficiently\n2]walking\n3]biking and swimming it is the great ex of aerobic exercise\n3]Try and do this type of exercise for about a half an hour a few times a week\n")
                print("MEDICINES:\nAccording to Ayurveda, effective COPD treatment requires one to do Nidanaparivarjana that includes modification of lifestyle and diet, and Shamana, a pacification treatment,\n and Shodhana, which is a biopurifactory method technique\n")


            else:
                print("Please enter a disease from list")

        elif(n>100):

            print("**Keep care at home if possible. Try to find care providers who are willing to provide care for your loved one outside a hospital setting and in the home. For some care providers this may mean home visits, for others it could mean telehealth appointments**\n")

        else:
            print("YOUR AGE IS LESS THAN '65 AGE' GROUP:")
            print("The age group less than 65 ,has immunity power is good. so there is a less chances of any major diseases")
            print("do daily exercies,intake of water minimum 5-6 lit,morning sunlight & healthy diet")
    if(v=='no'):
        print("\n\n**Take Vaccination First to stay in good health**")
        print("Tip:(Wear A Mask & Safely Using Hand Sanitizer...)")

    print("\t**GENERAL TIPS FOR ALL**\n#DO Daliy Exercies\n#daily walk 10-15 min in morning sun light\n#daily intake of one fruit\n#drink water 5-6 lit per day\n#prpoer meal\n#intake of protines,healthy fat etc...")
    if input('\n\n\n\nDo You Want To Continue?(y/n): ')!='y':
        break
# Out:
# Welcome to our healthy lifestyle and live a healthier onwards
# Some best Healthy and better life Tips
#
# DID YOU TAKE VACCINE(yes/no):yes
#
# ENTER YOUR 'AGE':66
#
# **Don't worry if you get sick from the list below.If it is an illness, what to do or what not to do for that illness and what care should be taken so that you can live your life longer for this ,read the following carefully..**
# DISEASE NAME=
# 1).diabetes
# 2).cancer
# 3).heart attack
# 4).paralysis
# 5).thyroid
# 6).hearing loss
# 7).backache
# 8).neck pain
# 9).depression
# 10).pulmonary
# 11).tuberculosis etc...
#
#
# Enter a Disease Name:heart attack
#
# PRECAUTIONS:
# 1]Quit smoking
# 2]keep check and control the chlestrol levels
# 3]control blood pressure levels
# 4]Exercise and be physically fit
# 5]Loose the extra weights
# 6]Choose a diet for a healthy heart
# 7]Get proper sleep
# 8]Manage stress(reduced stress)
#
# EXERCIES:
# 1]Choose an aerobic activity such as walking
# 2]swimming
# ...
